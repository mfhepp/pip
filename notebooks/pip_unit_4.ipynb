# %% [markdown]
# # Programmierung in Python <span class="tocSkip" />
#
# **Univ.-Prof. Dr. Martin Hepp,** Universität der Bundeswehr München
# <br /><br />
#
# ## Einheit 4: Datenvisualisierung <span class="tocSkip" />
# **Version: 2019-11-08** -- Work in progress ;-)
# <br /><br />
# [**http://www.ebusiness-unibw.org/wiki/Teaching/PIP**](http://www.ebusiness-unibw.org/wiki/Teaching/PIP)

# %% [markdown]
# # Grundlagen der Datenvisualisierung
# ## Ziel und Probleme
# ## Ansätze
# ## Datenvisualisierung in Python

# %% [markdown]
# # Matplotlib
# ## Geschichte
# ## Grundlagen der Anwendung
# - Beispiel
# - Anzeige in Jupyter Notebooks
# - Speichern als Datei
#
# ## Ressourcen

# %% [markdown]
# # Balkendiagramme

# %%
from matplotlib import pyplot as plt
plt.bar(range(5), [5, 7, 9, 3, 11])
plt.show()

# %% [markdown]
# # Liniendiagramme

# %%
from matplotlib import pyplot as plt
plt.plot(range(5), [5, 7, 9, 5, 11])
plt.show()

# %% [markdown]
# # Punktdiagramme
# Vgl. auch [hier](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot).

# %%
from matplotlib import pyplot as plt
plt.plot(range(5), [5, 7, 9, 5, 11], '.r')
plt.show()

# %% [markdown]
# # Boxplots

# %%
from matplotlib import pyplot as plt
plt.boxplot([0, 1, 5, 15, 4, 12, 5, 7, 9, 5, 11])
plt.show()

# %% [markdown]
# # Tortendiagramme

# %%
# auf Basis von https://matplotlib.org/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py
import matplotlib.pyplot as plt

labels = ['Java', 'Python', 'C++', 'Javascript']
sizes = [20, 45, 15, 20]
plt.pie(sizes, labels=labels)
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
from matplotlib import pyplot as plt
plt.scatter([5, 7, 9, 5, 11], [5, 7, 9, 5, 11])
plt.show()

# %% [markdown]
# # Heatmaps

# %%
# Beispiel aus https://stackoverflow.com/a/49608671/516699
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data, linewidth=0.5)
plt.show()

# %% [markdown]
# # Individualisierung und Gestaltung
# ## Titel
# ## Achsen und Achsenbeschriftungen
# ## Farben
# ## Legende
# ## Mehrere Diagramme

# %% [markdown]
# # Visualisierung von Daten mit geographischem Bezug
# Landkarten etc.
# Vgl. z.B. [hier](https://rabernat.github.io/research_computing/intro-to-basemap.html).

# %% [markdown]
# # Quellenangaben und weiterführende Literatur
# \[Pyt2019\]&nbsp;&nbsp;&nbsp;&nbsp;Python Software Foundation. Python 3.8.0 Documentation. [https://docs.python.org/3/](https://docs.python.org/3/).
#
# \[Ov2019\]&nbsp;&nbsp;&nbsp;&nbsp; Ohne Verfasser. Plotting Data with Matplotlib.
# https://howtothink.readthedocs.io/en/latest/PvL_H.html

# %% [markdown]
# # Vielen Dank! <a class="tocSkip">
#
# [**http://www.ebusiness-unibw.org/wiki/Teaching/PIP**](http://www.ebusiness-unibw.org/wiki/Teaching/PIP)
